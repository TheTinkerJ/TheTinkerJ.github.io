# %% [markdown]
# ## 个人博客-TheTinkerJ

# %%
def sayHello(hello):
    print(hello)

hello = "您好,我是猫哥!"
sayHello(hello)
# Out:
# 您好,我是猫哥!

# %%
import time
localtime = time.asctime( time.localtime(time.time()) )
print ("更新时间 :", localtime)
# Out:
# 更新时间 : Sat Apr 11 09:25:44 2020

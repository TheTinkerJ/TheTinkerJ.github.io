# %% [markdown]
# # 今天必须继续准备的内容
#
# - sql基础

# %% [markdown]
# ## sql 应知应会
#
#
# ### 选择
# ```sql
# select a from table
#
# select a.id,a.age,b.sex from
# (select id,age from table_1) a
# join
# (select id, sex from table_2) b
# on a.id =b.id
# ```
# ### 连接 join - on
#
# - inner join 左右都可以匹配的记录
# - left join 以左边为标准,右边可以空
# - right join 以右边为标准,左边可以空
# - outer join 左右均可以空
#
# ### union 表合并
#
# ### 去重复 distinct
#
# **count distinct**会将reducer强制限定为1 所以分开做,创建distinc的临时表
#
# ### group by 聚合函数
#
# ### 将数值型的变量转化为分类型的变量
#
# case when 条件函数

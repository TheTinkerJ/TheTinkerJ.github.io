# %% [markdown]
# # Spark项目知识

# %% [markdown]
# ## Kyro序列化
#
# ### 序列化的概念,得与失
#
# 序列化和反序列化: `序列化` (Serialization)是将对象的状态信息转换为可以存储或传输的形式的过程。在序列化期间，`对象`将其当前状态写入到临时或持久性存储区.以后，可以通过从存储区中读取或`反序列化`对象的状态，重新创建该对象.
#
# 对象实例的`所有字段`都会被序列化，这意味着数据会被表示为实例的序列化数据.
#
# 这就给安全性带了问题,所有字段序列化就意味着`访问规则`在序列化和反序列化的过程中会失效.
#
# 如果可能，应该使该对象`不可序列化`。如果它必须为`可序列化`的，请尝试生成`特定字段`来保存不可序列化的重要数据。如果无法实现这一点，则应注意该数据会被公开给任何拥有`序列化权限`的代码，并确保不让任何`恶意代码`获得该权限。
#
# ### spark中的序列化
#
# 需求:
# - 分发给Executor上的Task
# - 需要缓存的RDD（前提是使用序列化方式缓存）
# - 广播变量
# - Shuffle过程中的数据缓存
# - 使用receiver方式接收的流数据缓存
# - 算子函数中使用的外部变量
#
# 总的来说是一种时间换空间的方法
#
# #### JavaSerializer
#
# - Spark 默认的序列化器是 JAVA 自带的 ObjectOutputStream
# - 任何实现了 java.io.Serializable 接口的对象，都能被序列化
# - 还可以通过扩展 java.io.Externalizable 来控制序列化性能
#
# 很灵活但是性能差速度慢,同时空间并没有优化多少
#
# #### KryoSerializer
#
# `conf.set("spark.serializer","org.apache.spark.serializer.KryoSerializer") `
#
#
# - 这个设置`"spark.serializer"`会控制worker节点之间的混洗数据序列化格式
# - 控制RDD存到磁盘上的序列化格式
# - 任何org.apache.spark.serializer的子类都可以被序列化
# - 需要在程序中 register 需要序列化的类型
# - 如果你不注册需要序列化的自定义类型，Kryo也能工作，不过每一个对象实例的序列化结果都会包含一份完整的类名，这有点浪费空间。

# %%
from graphviz import Digraph


dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

dot
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\condaEnv\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     158     try:
# --> 159         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     160     except OSError as e:
#
# D:\condaEnv\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt

import mglearn
 
mglearn.plots.plot_animal_tree()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f0184ecdd99d> in <module>
#       4 import scipy
#       5 import matplotlib.pyplot as plt
# ----> 6 import mglearn
#       7
#       8 mglearn.plots.plot_animal_tree()
#
# ModuleNotFoundError: No module named 'mglearn'

# %%
# %matplotlib inline
import graphviz
d = graphviz.Digraph()
d.edge("hello","world")
d
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\condaEnv\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     158     try:
# --> 159         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     160     except OSError as e:
#
# D:\condaEnv\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

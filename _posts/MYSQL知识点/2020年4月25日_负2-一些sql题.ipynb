# %% [markdown]
# MYSQL语法操作:
#
# ```MYSQL
# select 查询列表
# from 表1 别名 [连接类型]
# jion 表2 别名
# on 连接条件
# [where 筛选条件]
# [group by 分组]
# [having 筛选条件]
# [order by 排序列表]
# ```

# %% [markdown]
#  ## 日子计算
#
#  DATEDIFF(w1.RecordDate,w2.RecordDate)=-1
#
#  MYSQL中计算日前的函数,`前一天`-`后一天`=`-1`
